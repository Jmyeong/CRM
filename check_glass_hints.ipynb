# %% [markdown]
# View Glass hints

# %%
import numpy as np
import matplotlib.pyplot as plt
date = "2025_05_08"
drive = 13
image_num =2
index = 120
gh_path = f"/ssd1/jm_data/depth/ssl/monodepth2/jbnu_stereo/2025_05_08/2025_05_08_drive_{str(drive).zfill(4)}_sync/proj_depth/groundtruth_crm/image_02/{str(index).zfill(10)}.npy"
gt_path = f"/ssd1/jm_data/depth/ssl/monodepth2/jbnu_stereo/2025_05_08/2025_05_08_drive_{str(drive).zfill(4)}_sync/proj_depth/groundtruth/image_02/{str(index).zfill(10)}.npy"

gh = np.load(gh_path)
gt = np.load(gt_path)
print(np.unique(gh))
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(gh, cmap="magma_r")
# plt.subplot(1,2,2)
# plt.imshow(gt, cmap="magma_r")
# Out:
# [ 0.96639025  0.96713394  0.96783966 ... 40.666943   40.6741
#  40.71206   ]

# %%
# Out:
# ✅ 데이터 복구 완료! shape: (230432,)

# %%
# Out:
# ❌ 오류 발생: /ssd1/jm_data/depth/ssl/monodepth2/jbnu_stereo/2025_02_28/2025_02_28_drive_0003_sync/proj_depth/groundtruth/image_03/0000002700.npy - Cannot load file containing pickled data when allow_pickle=False
