# %%
import numpy as np
import matplotlib.pyplot as plt

pred = np.load("/ssd1/jm_data/depth/ssl/SfMNeXt-Impl/depth_vis/video/2025_05_08_drive_0007_sync/image_02/0000000210.npy")
plt.imshow(pred, cmap="magma_r")
plt.axis("off")
# Out:
# (-0.5, 639.5, 351.5, -0.5)
