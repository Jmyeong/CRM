# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from layers import disp_to_depth

path = os.path.join("logs/jbnu_stereo_teacher/models/weights_19/disps_jbnu_stereo_split.npy")
pred = np.load(path)
pred = pred[-30]
pred_depth, _ = disp_to_depth(pred, 0.001, 50.0)

print(np.unique(pred_depth))

plt.imshow(pred_depth, cmap="magma_r")
# Out:
# [148.99036629 149.00851554 149.07184421 ... 915.61384892 916.1624987
#  916.45902588]
